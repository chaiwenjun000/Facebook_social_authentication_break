# %%
import face_recognition
import cv2
import os

# %%
face_recognition.compare_faces
# 照片路径
friends_images_path = './train_img/'
predict_images_path  = './predict_images2/'

# 已知照片的人脸编码列表
known_face_encodings = []
#名字列表
known_face_names = []

# 遍历路径下的文件
for filename in os.listdir(friends_images_path):
    # 忽略macos 的 .DS_Store
    if filename.startswith('.'):
        continue
    image_path = friends_images_path + '/' + filename
    print (image_path)
    friend_image = face_recognition.load_image_file(image_path)
    # 只获取第一个人的 人脸编码 和 名称
    #print (face_recognition.face_encodings(friend_image))
    #break
    #print(face_recognition.face_encodings(friend_image))
    
    friend_face_encoding = face_recognition.face_encodings(friend_image)
    if len(friend_face_encoding) != 0:
        friend_face_encoding = friend_face_encoding[0]
        known_face_encodings.append(friend_face_encoding)
        known_face_names.append(filename.split('.')[0])
print (known_face_names)
# Out:
# ./train_img//Kailash Babu1.jpg
# ./train_img//Shavaughn Henry4.jpg
# ./train_img//Livay Hasselnook.jpg
# ./train_img//Kailash Babu3.jpg
# ./train_img//Kailash Babu2.jpg
# ./train_img//Shavaughn Henry1.jpg
# ./train_img//Shavaughn Henry2.jpg
# ./train_img//Shavaughn Henry3.jpg
# ./train_img//Djamel Djajo1.jpg
# ./train_img//Toet Vinisi04.jpg
# ./train_img//Shevonne Baird2.jpg
# ./train_img//Parash Moktan4.jpg
# ./train_img//Shevonne Baird3.jpg
# ./train_img//Rendel Feller4.jpg
# ./train_img//Toet Vinisi05.jpg
# ./train_img//DS Miriamm2.jpg
# ./train_img//Djamel Djajo2.jpg
# ./train_img//Shevonne Baird1.jpg
# ./train_img//Nandy Ramos4.jpg
# ./train_img//DS Miriamm1.jpg
# ./train_img//Toet Vinisi02.jpg
# ./train_img//Rendel Feller3.jpg
# ./train_img//Nandy Ramos1.jpg
# ./train_img//Parash Moktan3.jpg
# ./train_img//Parash Moktan2.jpg
# ./train_img//Rendel Feller2.jpg
# ./train_img//Regina Eno1.jpg
# ./train_img//Toet Vinisi1.jpg
# ./train_img//Toet Vinisi03.jpg
# ./train_img//OueMina Joel1.jpg
# ./train_img//Toet Vinisi3.jpg
# ./train_img//Regina Eno3.jpg
# ./train_img//Nandy Ramos2.jpg
# ./train_img//Parash Moktan1.jpg
# ./train_img//Nandy Ramos3.jpg
# ./train_img//Rendel Feller1.jpg
# ./train_img//Regina Eno2.jpg
# ./train_img//Sidney Lashae.jpg
# ./train_img//Toet Vinisi2.jpg
# ./train_img//Jeanty Mayarnho Yann3.jpg
# ./train_img//Alexa Bruny1.jpg
# ./train_img//OG Smith2.jpg
# ./train_img//Jeanty Mayarnho Yann2.jpg
# ./train_img//Sheila Swerissen4.jpg
# ./train_img//Alexa Bruny2.jpg
# ./train_img//OG Smith1.jpg
# ./train_img//Cleudiane Silva5.jpg
# ./train_img//Cleudiane Silva4.jpg
# ./train_img//Sidney Lashae1.jpg
# ./train_img//Alexa Bruny3.jpg
# ./train_img//Jeanty Mayarnho Yann1.jpg
# ./train_img//Sheila Swerissen1.jpg
# ./train_img//Cleudiane Silva1.jpg
# ./train_img//Jeanty Mayarnho Yann4.jpg
# ./train_img//Atis Mimik Polisca1.jpg
# ./train_img//Sheila Swerissen2.jpg
# ./train_img//Cleudiane Silva3.jpg
# ./train_img//Cleudiane Silva2.jpg
# ./train_img//Sheila Swerissen3.jpg
# ./train_img//Atis Mimik Polisca2.jpg
# ./train_img//Antoine Sana2.jpg
# ./train_img//Livay Hasselnook.jpg3.jpg
# ./train_img//Antoine Sana3.jpg
# ./train_img//Antoine Sana1.jpg
# ./train_img//Jean Neal Gregor Pyunfie3.jpg
# ./train_img//Antoine Sana4.jpg
# ./train_img//Agnes Tabelin2.jpg
# ./train_img//Ashley Nussy Tyreana Morgan2.jpg
# ./train_img//柴文俊1.jpg
# ./train_img//Agnes Tabelin3.jpg
# ./train_img//Jean Neal Gregor Pyunfie2.jpg
# ./train_img//Ashley Nussy Tyreana Morgan1.jpg
# ./train_img//Agnes Tabelin1.jpg
# ./train_img//Jean Neal Gregor Pyunfie1.jpg
# ['Shavaughn Henry4', 'Livay Hasselnook', 'Kailash Babu3', 'Kailash Babu2', 'Shavaughn Henry1', 'Shavaughn Henry2', 'Shavaughn Henry3', 'Djamel Djajo1', 'Toet Vinisi04', 'Shevonne Baird2', 'Parash Moktan4', 'Shevonne Baird3', 'Rendel Feller4', 'Toet Vinisi05', 'Djamel Djajo2', 'Shevonne Baird1', 'Nandy Ramos4', 'DS Miriamm1', 'Toet Vinisi02', 'Rendel Feller3', 'Nandy Ramos1', 'Parash Moktan3', 'Parash Moktan2', 'Rendel Feller2', 'Regina Eno1', 'Toet Vinisi03', 'Toet Vinisi3', 'Regina Eno3', 'Nandy Ramos2', 'Nandy Ramos3', 'Rendel Feller1', 'Regina Eno2', 'Sidney Lashae', 'Toet Vinisi2', 'Alexa Bruny1', 'OG Smith2', 'Jeanty Mayarnho Yann2', 'Sheila Swerissen4', 'Alexa Bruny2', 'OG Smith1', 'Cleudiane Silva5', 'Cleudiane Silva4', 'Sidney Lashae1', 'Alexa Bruny3', 'Jeanty Mayarnho Yann1', 'Sheila Swerissen1', 'Cleudiane Silva1', 'Jeanty Mayarnho Yann4', 'Atis Mimik Polisca1', 'Sheila Swerissen2', 'Cleudiane Silva3', 'Cleudiane Silva2', 'Sheila Swerissen3', 'Atis Mimik Polisca2', 'Antoine Sana2', 'Livay Hasselnook', 'Antoine Sana3', 'Antoine Sana1', 'Jean Neal Gregor Pyunfie3', 'Antoine Sana4', 'Agnes Tabelin2', 'Ashley Nussy Tyreana Morgan2', '柴文俊1', 'Agnes Tabelin3', 'Ashley Nussy Tyreana Morgan1', 'Agnes Tabelin1', 'Jean Neal Gregor Pyunfie1']

# %%
def sort_dict(dict_words):
    """
    字典排序
    :param dict_words:
    :return:
    """
    keys = dict_words.keys()
    values = dict_words.values()
    list_one = [(key, val) for key, val in zip(keys, values)]
    list_sort = sorted(list_one, key=lambda x: x[1], reverse=False)
    return list_sort

# %%
predict_images_path = './clean_img/' 
for filename in os.listdir(predict_images_path):
     # 忽略.DS_Store
    if filename.startswith('.'):
        continue
    image_path = predict_images_path + '/' + filename
    print (image_path)
    predict_image = face_recognition.load_image_file(image_path)
    predict_face_encodings = face_recognition.face_encodings(predict_image)
   # print(predict_face_encodings)
    #存储每一张脸的位置信息
    face_locations = face_recognition.face_locations(predict_image)
    # 遍历一张图中多个脸 编码信息
    for i in range(len(predict_face_encodings)):
        predict_encoding = predict_face_encodings[i]
        face_location = face_locations[i]
        top, right, bottom,left = face_location
        # 在照片中标注人脸
        cv2.rectangle(predict_image,(left,top),(right,bottom),(0,255,0),2)
        # 将已知人脸的编码，和未知人脸的编码作比较，结果存入results数组中
        # results 数组中的每一个元素都是True 或者 False
        # results 数组与已知人脸一一对应
        face_distances = face_recognition.face_distance(known_face_encodings, predict_encoding)
        ans = {}
        for i, face_distance in enumerate(face_distances):
            #print("The test image has a distance of {:.2} from known image #{}".format(face_distance, i))
            #print("- With a normal cutoff of 0.6, would the test image match the known image? {}".format(face_distance < 0.6))
            #print("- With a very strict cutoff of 0.5, would the test image match the known image? {}".format(face_distance < 0.5))
            name = known_face_names[i]
            ans[name] = face_distance
            #print(name,face_distance)
        ans = sort_dict(ans)
        # 方法1
        print ('遍历列表方法1：')
        for i in ans:
            print ("序号：%s  值：%s" % (ans.index(i) + 1, i[0]))
        
        cnt = 0
        for key in ans:  
            cnt += 1
            if cnt == 1:
                print('识别结果',key)
                print('备选项：')
                continue
            print(key)
            if cnt == 6:
                break
            
#         results = face_recognition.compare_faces(known_face_encodings,predict_encoding)
#         for j in range (len(results)):
#             if results[j]:
#                 name = known_face_names[j]
#                 print ('the picture is '+ filename+ ", predicted the people is "+name)
#                 # 在图片中标注姓名
#                 cv2.putText(predict_image,name,(left-10,top-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
#                 break
#     predict_image_rgb = cv2.cvtColor(predict_image, cv2.COLOR_BGR2RGB)
#     cv2.imshow("Output",predict_image_rgb)
#     cv2.waitKey(0)
# Out:
# ./clean_img//DS Miriamm1.jpg
# 遍历列表方法1：
# 序号：1  值：('DS Miriamm1', 0.0)
# 序号：2  值：('Sidney Lashae', 0.6519229697366349)
# 序号：3  值：('Cleudiane Silva5', 0.6532416758595447)
# 序号：4  值：('Sheila Swerissen2', 0.6547847460128495)
# 序号：5  值：('Sheila Swerissen3', 0.6611022518144792)
# 序号：6  值：('Sheila Swerissen4', 0.6868993357714207)
# 序号：7  值：('Jean Neal Gregor Pyunfie3', 0.6904216584442283)
# 序号：8  值：('Cleudiane Silva1', 0.7075505002329016)
# 序号：9  值：('Sheila Swerissen1', 0.72241810390217)
# 序号：10  值：('Cleudiane Silva3', 0.7330928983976167)
# 序号：11  值：('Sidney Lashae1', 0.7474017009136471)
# 序号：12  值：('Cleudiane Silva2', 0.7521756686482031)
# 序号：13  值：('Cleudiane Silva4', 0.7552998372283305)
# 序号：14  值：('Ashley Nussy Tyreana Morgan1', 0.7646301931997542)
# 序号：15  值：('Shevonne Baird1', 0.7655220566497473)
# 序号：16  值：('Shevonne Baird3', 0.7729960846292037)
# 序号：17  值：('Shevonne Baird2', 0.7791048136639825)
# 序号：18  值：('Livay Hasselnook', 0.7918294779612072)
# 序号：19  值：('Toet Vinisi03', 0.7945790032514239)
# 序号：20  值：('Toet Vinisi3', 0.7945790032514239)
# 序号：21  值：('Kailash Babu3', 0.8022581807518067)
# 序号：22  值：('Jean Neal Gregor Pyunfie1', 0.8235513565921695)
# 序号：23  值：('Rendel Feller2', 0.8264456039796866)
# 序号：24  值：('Ashley Nussy Tyreana Morgan2', 0.8264538300057507)
# 序号：25  值：('Toet Vinisi05', 0.8320720749794435)
# 序号：26  值：('Parash Moktan2', 0.8355214224801119)
# 序号：27  值：('Regina Eno2', 0.83698999115249)
# 序号：28  值：('Toet Vinisi02', 0.8397936043831512)
# 序号：29  值：('Toet Vinisi2', 0.8397936043831512)
# 序号：30  值：('Agnes Tabelin2', 0.8447579823436068)
# 序号：31  值：('Parash Moktan3', 0.8455426733761656)
# 序号：32  值：('Alexa Bruny2', 0.8489026463003666)
# 序号：33  值：('Regina Eno1', 0.8490707807182547)
# 序号：34  值：('柴文俊1', 0.8629651089529152)
# 序号：35  值：('Rendel Feller1', 0.8646899238309511)
# 序号：36  值：('Atis Mimik Polisca2', 0.864789086718008)
# 序号：37  值：('Regina Eno3', 0.8654160992272452)
# 序号：38  值：('Parash Moktan4', 0.8680453422824409)
# 序号：39  值：('Alexa Bruny3', 0.8704843952659402)
# 序号：40  值：('Nandy Ramos4', 0.8716440216993618)
# 序号：41  值：('Jeanty Mayarnho Yann2', 0.8729916507061143)
# 序号：42  值：('Nandy Ramos3', 0.8733284349729447)
# 序号：43  值：('Antoine Sana4', 0.8747643275375201)
# 序号：44  值：('Agnes Tabelin1', 0.8769563756427943)
# 序号：45  值：('Nandy Ramos1', 0.8820573342257627)
# 序号：46  值：('Agnes Tabelin3', 0.8827057351325145)
# 序号：47  值：('Toet Vinisi04', 0.8830423875642427)
# 序号：48  值：('Alexa Bruny1', 0.8833596383178705)
# 序号：49  值：('Jeanty Mayarnho Yann4', 0.8854392522342446)
# 序号：50  值：('Jeanty Mayarnho Yann1', 0.890728615287524)
# 序号：51  值：('Rendel Feller3', 0.8935421834595746)
# 序号：52  值：('Rendel Feller4', 0.895295944782054)
# 序号：53  值：('Kailash Babu2', 0.9037165869889372)
# 序号：54  值：('Nandy Ramos2', 0.9202864631034742)
# 序号：55  值：('Antoine Sana1', 0.9316421977100691)
# 序号：56  值：('Shavaughn Henry2', 0.9500684499609606)
# 序号：57  值：('Antoine Sana2', 0.9506930171441854)
# 序号：58  值：('Shavaughn Henry4', 0.9596903603868974)
# 序号：59  值：('Antoine Sana3', 0.9643745241861705)
# 序号：60  值：('OG Smith1', 0.9653119516626262)
# 序号：61  值：('Atis Mimik Polisca1', 0.9823872611564498)
# 序号：62  值：('Shavaughn Henry3', 0.9918628132102294)
# 序号：63  值：('Shavaughn Henry1', 1.0088598202536694)
# 序号：64  值：('OG Smith2', 1.0241880948102808)
# 序号：65  值：('Djamel Djajo2', 1.0416640550348952)
# 序号：66  值：('Djamel Djajo1', 1.0541281517293117)
# 识别结果 ('DS Miriamm1', 0.0)
# 备选项：
# ('Sidney Lashae', 0.6519229697366349)
# ('Cleudiane Silva5', 0.6532416758595447)
# ('Sheila Swerissen2', 0.6547847460128495)
# ('Sheila Swerissen3', 0.6611022518144792)
# ('Sheila Swerissen4', 0.6868993357714207)
