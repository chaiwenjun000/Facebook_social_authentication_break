# %%
# -*- coding: utf-8 -*-

from skimage import io,transform
import glob
import os
import tensorflow as tf
import numpy as np
import time

#数据集地址
path='./Faces2/'
#模型保存地址
model_path='./Model/model2.ckpt'

#将所有的图片resize成100*100
w=100
h=100
c=3


#读取图片
def read_img(path):
    cate=[path+'/'+x for x in os.listdir(path) if os.path.isdir(path+'/'+x)]
    imgs=[]
    labels=[]
    for idx,folder in enumerate(cate):
        for im in glob.glob(folder+'/*.jpg'):
            #print('reading the images:%s'%(im))
            img=io.imread(im)
            img=transform.resize(img,(w,h))
            imgs.append(img)
            labels.append(idx)
    
    print('img',img)
    print('labels',labels)
    return np.asarray(imgs,np.float32),np.asarray(labels,np.int32)
data,label=read_img(path)


#打乱顺序
num_example=data.shape[0]
arr=np.arange(num_example)
np.random.shuffle(arr)
data=data[arr]
label=label[arr]


#将所有数据分为训练集和验证集
ratio=0.8
s=np.int(num_example*ratio)
x_train=data[:s]
y_train=label[:s]
x_val=data[s:]
y_val=label[s:]

#-----------------构建网络----------------------
#占位符
x=tf.placeholder(tf.float32,shape=[None,w,h,c],name='x')
y_=tf.placeholder(tf.int32,shape=[None,],name='y_')

#前向传播
def inference(input_tensor, train, regularizer):
    #卷积层
    #padding='SAME' 使用0来填充
    with tf.variable_scope('layer1-conv1',reuse=tf.AUTO_REUSE):
        conv1_weights = tf.get_variable("weight",[5,5,3,32],initializer=tf.truncated_normal_initializer(stddev=0.1))
        conv1_biases = tf.get_variable("bias", [32], initializer=tf.constant_initializer(0.0))
        conv1 = tf.nn.conv2d(input_tensor, conv1_weights, strides=[1, 1, 1, 1], padding='SAME')
        relu1 = tf.nn.relu(tf.nn.bias_add(conv1, conv1_biases))
    
    #池化层
    with tf.name_scope("layer2-pool1"):
        pool1 = tf.nn.max_pool(relu1, ksize = [1,2,2,1],strides=[1,2,2,1],padding="VALID")
    
    #卷积层
    with tf.variable_scope("layer3-conv2",reuse=tf.AUTO_REUSE):
        conv2_weights = tf.get_variable("weight",[5,5,32,64],initializer=tf.truncated_normal_initializer(stddev=0.1))
        conv2_biases = tf.get_variable("bias", [64], initializer=tf.constant_initializer(0.0))
        conv2 = tf.nn.conv2d(pool1, conv2_weights, strides=[1, 1, 1, 1], padding='SAME')
        relu2 = tf.nn.relu(tf.nn.bias_add(conv2, conv2_biases))
    
    #池化层
    with tf.name_scope("layer4-pool2"):
        pool2 = tf.nn.max_pool(relu2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')
    
    #卷积层
    with tf.variable_scope("layer5-conv3",reuse=tf.AUTO_REUSE):
        conv3_weights = tf.get_variable("weight",[3,3,64,128],initializer=tf.truncated_normal_initializer(stddev=0.1))
        conv3_biases = tf.get_variable("bias", [128], initializer=tf.constant_initializer(0.0))
        conv3 = tf.nn.conv2d(pool2, conv3_weights, strides=[1, 1, 1, 1], padding='SAME')
        relu3 = tf.nn.relu(tf.nn.bias_add(conv3, conv3_biases))
    
    #池化层
    with tf.name_scope("layer6-pool3"):
        pool3 = tf.nn.max_pool(relu3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    #卷积层
    with tf.variable_scope("layer7-conv4",reuse=tf.AUTO_REUSE):
        conv4_weights = tf.get_variable("weight",[3,3,128,128],initializer=tf.truncated_normal_initializer(stddev=0.1))
        conv4_biases = tf.get_variable("bias", [128], initializer=tf.constant_initializer(0.0))
        conv4 = tf.nn.conv2d(pool3, conv4_weights, strides=[1, 1, 1, 1], padding='SAME')
        relu4 = tf.nn.relu(tf.nn.bias_add(conv4, conv4_biases))

    #池化层
    with tf.name_scope("layer8-pool4"):
        pool4 = tf.nn.max_pool(relu4, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')
        nodes = 6*6*128
        reshaped = tf.reshape(pool4,[-1,nodes])

    #全连接层
    with tf.variable_scope('layer9-fc1',reuse=tf.AUTO_REUSE):
        fc1_weights = tf.get_variable("weight", [nodes, 1024],
                                      initializer=tf.truncated_normal_initializer(stddev=0.1))
        if regularizer != None: tf.add_to_collection('losses', regularizer(fc1_weights))
        fc1_biases = tf.get_variable("bias", [1024], initializer=tf.constant_initializer(0.1))

        fc1 = tf.nn.relu(tf.matmul(reshaped, fc1_weights) + fc1_biases)
        if train: fc1 = tf.nn.dropout(fc1, 0.5)

    #全连接层
    with tf.variable_scope('layer10-fc2',reuse=tf.AUTO_REUSE):
        fc2_weights = tf.get_variable("weight", [1024, 512],
                                      initializer=tf.truncated_normal_initializer(stddev=0.1))
        if regularizer != None: tf.add_to_collection('losses', regularizer(fc2_weights))
        fc2_biases = tf.get_variable("bias", [512], initializer=tf.constant_initializer(0.1))

        fc2 = tf.nn.relu(tf.matmul(fc1, fc2_weights) + fc2_biases)
        if train: fc2 = tf.nn.dropout(fc2, 0.5)
    
    #全连接层
    with tf.variable_scope('layer11-fc3',reuse=tf.AUTO_REUSE):
        fc3_weights = tf.get_variable("weight", [512, 115],
                                      initializer=tf.truncated_normal_initializer(stddev=0.1))
        if regularizer != None: tf.add_to_collection('losses', regularizer(fc3_weights))
        fc3_biases = tf.get_variable("bias", [115], initializer=tf.constant_initializer(0.1))
        logit = tf.matmul(fc2, fc3_weights) + fc3_biases

    return logit

#---------------------------网络结束---------------------------
regularizer = tf.contrib.layers.l2_regularizer(0.0001)
logits = inference(x,False,regularizer)

#(小处理)将logits乘以1赋值给logits_eval，定义name，方便在后续调用模型时通过tensor名字调用输出tensor
b = tf.constant(value = 1,dtype = tf.float32)
logits_eval = tf.multiply(logits,b,name='logits_eval') 

loss=tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=y_)
train_op=tf.train.AdamOptimizer(learning_rate=0.001).minimize(loss)
correct_prediction = tf.equal(tf.cast(tf.argmax(logits,1),tf.int32), y_)    
acc= tf.reduce_mean(tf.cast(correct_prediction, tf.float32))


#按批次取数据
def minibatches(inputs=None, targets=None, batch_size=None, shuffle=False):
    assert len(inputs) == len(targets)
    if shuffle:
        indices = np.arange(len(inputs))
        np.random.shuffle(indices)
    for start_idx in range(0, len(inputs) - batch_size + 1, batch_size):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batch_size]
        else:
            excerpt = slice(start_idx, start_idx + batch_size)
        yield inputs[excerpt], targets[excerpt]


#训练和测试数据，可将n_epoch（轮次）设置更大一些
n_epoch=10 
batch_size=64
saver=tf.train.Saver()
sess=tf.Session()  
sess.run(tf.global_variables_initializer())
for epoch in range(n_epoch):
    start_time = time.time()

    #training
    train_loss, train_acc, n_batch = 0, 0, 0
    for x_train_a, y_train_a in minibatches(x_train, y_train, batch_size, shuffle=True):
        _,err,ac=sess.run([train_op,loss,acc], feed_dict={x: x_train_a, y_: y_train_a})
        train_loss += err; train_acc += ac; n_batch += 1
    print("   train loss: %f" % (np.sum(train_loss)/ n_batch))
    print("   train acc: %f" % (np.sum(train_acc)/ n_batch))

    #validation
    val_loss, val_acc, n_batch = 0, 0, 0
    for x_val_a, y_val_a in minibatches(x_val, y_val, batch_size, shuffle=False):
        err, ac = sess.run([loss,acc], feed_dict={x: x_val_a, y_: y_val_a})
        val_loss += err; val_acc += ac; n_batch += 1
    print("   validation loss: %f" % (np.sum(val_loss)/ n_batch))
    print("   validation acc: %f" % (np.sum(val_acc)/ n_batch))
saver.save(sess,model_path)
sess.close()
# Out:
# reading the images:./Faces2//German_Khan/German_Khan_0001.jpg
# reading the images:./Faces2//Stefano_Gabbana/Stefano_Gabbana_0001.jpg
# reading the images:./Faces2//Dragan_Covic/Dragan_Covic_0001.jpg
# reading the images:./Faces2//Jeff_Hornacek/Jeff_Hornacek_0001.jpg
# reading the images:./Faces2//Sureyya_Ayhan/Sureyya_Ayhan_0001.jpg
# reading the images:./Faces2//Deb_Santos/Deb_Santos_0001.jpg
# reading the images:./Faces2//Bob_Newhart/Bob_Newhart_0001.jpg
# reading the images:./Faces2//Wang_Hailan/Wang_Hailan_0001.jpg
# reading the images:./Faces2//Paul_McNulty/Paul_McNulty_0002.jpg
# reading the images:./Faces2//Paul_McNulty/Paul_McNulty_0001.jpg
# reading the images:./Faces2//Jimmy_Iovine/Jimmy_Iovine_0001.jpg
# reading the images:./Faces2//Claudia_Pechstein/Claudia_Pechstein_0001.jpg
# reading the images:./Faces2//Claudia_Pechstein/Claudia_Pechstein_0003.jpg
# reading the images:./Faces2//Claudia_Pechstein/Claudia_Pechstein_0002.jpg
# reading the images:./Faces2//Claudia_Pechstein/Claudia_Pechstein_0005.jpg
# reading the images:./Faces2//Claudia_Pechstein/Claudia_Pechstein_0004.jpg
# reading the images:./Faces2//Ranil_Wickremasinghe/Ranil_Wickremasinghe_0002.jpg
# reading the images:./Faces2//Ranil_Wickremasinghe/Ranil_Wickremasinghe_0003.jpg
# reading the images:./Faces2//Ranil_Wickremasinghe/Ranil_Wickremasinghe_0001.jpg
# reading the images:./Faces2//Ben_Chandler/Ben_Chandler_0001.jpg
# reading the images:./Faces2//Mark_Komara/Mark_Komara_0001.jpg
# reading the images:./Faces2//Rand_Beers/Rand_Beers_0001.jpg
# reading the images:./Faces2//Joanne_Woodward/Joanne_Woodward_0001.jpg
# reading the images:./Faces2//John_Bond/John_Bond_0001.jpg
# reading the images:./Faces2//Reginald_Hudlin/Reginald_Hudlin_0001.jpg
# reading the images:./Faces2//JK_Rowling/JK_Rowling_0005.jpg
# reading the images:./Faces2//JK_Rowling/JK_Rowling_0006.jpg
# reading the images:./Faces2//JK_Rowling/JK_Rowling_0002.jpg
# reading the images:./Faces2//JK_Rowling/JK_Rowling_0003.jpg
# reading the images:./Faces2//JK_Rowling/JK_Rowling_0001.jpg
# reading the images:./Faces2//Shinya_Taniguchi/Shinya_Taniguchi_0001.jpg
# reading the images:./Faces2//Tony_Curtis/Tony_Curtis_0002.jpg
# reading the images:./Faces2//Tony_Curtis/Tony_Curtis_0001.jpg
# reading the images:./Faces2//Laurie_Pirtle/Laurie_Pirtle_0001.jpg
# reading the images:./Faces2//Angel_Maza/Angel_Maza_0001.jpg
# reading the images:./Faces2//Ray_Sherman/Ray_Sherman_0001.jpg
# reading the images:./Faces2//Nancy_Powell/Nancy_Powell_0001.jpg
# reading the images:./Faces2//Kathryn_Tucker/Kathryn_Tucker_0001.jpg
# reading the images:./Faces2//Gro_Harlem_Brundtland/Gro_Harlem_Brundtland_0002.jpg
# reading the images:./Faces2//Gro_Harlem_Brundtland/Gro_Harlem_Brundtland_0001.jpg
# reading the images:./Faces2//Jacqueline_Marris/Jacqueline_Marris_0001.jpg
# reading the images:./Faces2//Mikhail_Gorbachev/Mikhail_Gorbachev_0002.jpg
# reading the images:./Faces2//Mikhail_Gorbachev/Mikhail_Gorbachev_0001.jpg
# reading the images:./Faces2//Takuma_Sato/Takuma_Sato_0001.jpg
# reading the images:./Faces2//Ray_Lewis/Ray_Lewis_0001.jpg
# reading the images:./Faces2//Hank_Aaron/Hank_Aaron_0001.jpg
# reading the images:./Faces2//Chip_Knight/Chip_Knight_0001.jpg
# reading the images:./Faces2//Tracee_Treadwell/Tracee_Treadwell_0001.jpg
# reading the images:./Faces2//Ronald_Young_Jr/Ronald_Young_Jr_0001.jpg
# reading the images:./Faces2//Gustavo_Cisneros/Gustavo_Cisneros_0001.jpg
# reading the images:./Faces2//Jack_Osbourne/Jack_Osbourne_0001.jpg
# reading the images:./Faces2//Isidro_Pastor/Isidro_Pastor_0001.jpg
# reading the images:./Faces2//Mike_Duke/Mike_Duke_0001.jpg
# reading the images:./Faces2//Natalie_Williams/Natalie_Williams_0001.jpg
# reading the images:./Faces2//Angela_Lansbury/Angela_Lansbury_0002.jpg
# reading the images:./Faces2//Angela_Lansbury/Angela_Lansbury_0001.jpg
# reading the images:./Faces2//Cathy_Freeman/Cathy_Freeman_0002.jpg
# reading the images:./Faces2//Cathy_Freeman/Cathy_Freeman_0001.jpg
# reading the images:./Faces2//Milt_Palacio/Milt_Palacio_0001.jpg
# reading the images:./Faces2//Wilbert_Elki_Meza_Majino/Wilbert_Elki_Meza_Majino_0001.jpg
# reading the images:./Faces2//Ekke_Hard_Forberg/Ekke_Hard_Forberg_0001.jpg
# reading the images:./Faces2//Jack_Welch/Jack_Welch_0001.jpg
# reading the images:./Faces2//Nizar_Trabelsi/Nizar_Trabelsi_0001.jpg
# reading the images:./Faces2//Gonzalo_Barrientos/Gonzalo_Barrientos_0001.jpg
# reading the images:./Faces2//Jason_Biggs/Jason_Biggs_0001.jpg
# reading the images:./Faces2//Lisa_Leslie/Lisa_Leslie_0001.jpg
# reading the images:./Faces2//Tayyeb_Abdel_Rahim/Tayyeb_Abdel_Rahim_0001.jpg
# reading the images:./Faces2//Tyron_Garner/Tyron_Garner_0001.jpg
# reading the images:./Faces2//Tyron_Garner/Tyron_Garner_0002.jpg
# reading the images:./Faces2//John_Sidgmore/John_Sidgmore_0001.jpg
# reading the images:./Faces2//Alexander_Payne/Alexander_Payne_0001.jpg
# reading the images:./Faces2//Brad_Brownell/Brad_Brownell_0001.jpg
# reading the images:./Faces2//John_Duprey/John_Duprey_0001.jpg
# reading the images:./Faces2//Ainsworth_Dyer/Ainsworth_Dyer_0001.jpg
# reading the images:./Faces2//Christine_Ebersole/Christine_Ebersole_0002.jpg
# reading the images:./Faces2//Christine_Ebersole/Christine_Ebersole_0001.jpg
# reading the images:./Faces2//Amer_al-Saadi/Amer_al-Saadi_0004.jpg
# reading the images:./Faces2//Amer_al-Saadi/Amer_al-Saadi_0001.jpg
# reading the images:./Faces2//Amer_al-Saadi/Amer_al-Saadi_0002.jpg
# reading the images:./Faces2//Amer_al-Saadi/Amer_al-Saadi_0003.jpg
# reading the images:./Faces2//Alison_Lohman/Alison_Lohman_0001.jpg
# reading the images:./Faces2//Alison_Lohman/Alison_Lohman_0002.jpg
# reading the images:./Faces2//Duane_Lee_Chapman/Duane_Lee_Chapman_0001.jpg
# reading the images:./Faces2//Duane_Lee_Chapman/Duane_Lee_Chapman_0002.jpg
# reading the images:./Faces2//Andre_Smith/Andre_Smith_0001.jpg
# reading the images:./Faces2//Iban_Mayo/Iban_Mayo_0002.jpg
# reading the images:./Faces2//Iban_Mayo/Iban_Mayo_0001.jpg
# reading the images:./Faces2//Jeong_Se-hyun/Jeong_Se-hyun_0009.jpg
# reading the images:./Faces2//Jeong_Se-hyun/Jeong_Se-hyun_0008.jpg
# reading the images:./Faces2//Jeong_Se-hyun/Jeong_Se-hyun_0001.jpg
# reading the images:./Faces2//Jeong_Se-hyun/Jeong_Se-hyun_0003.jpg
# reading the images:./Faces2//Jeong_Se-hyun/Jeong_Se-hyun_0002.jpg
# reading the images:./Faces2//Jeong_Se-hyun/Jeong_Se-hyun_0006.jpg
# reading the images:./Faces2//Jeong_Se-hyun/Jeong_Se-hyun_0007.jpg
# reading the images:./Faces2//Jeong_Se-hyun/Jeong_Se-hyun_0005.jpg
# reading the images:./Faces2//Jeong_Se-hyun/Jeong_Se-hyun_0004.jpg
# reading the images:./Faces2//Charles_Rogers/Charles_Rogers_0001.jpg
# reading the images:./Faces2//Eric_Rosser/Eric_Rosser_0001.jpg
# reading the images:./Faces2//Eric_Rosser/Eric_Rosser_0002.jpg
# reading the images:./Faces2//Ziwang_Xu/Ziwang_Xu_0001.jpg
# reading the images:./Faces2//Larry_Pleau/Larry_Pleau_0001.jpg
# reading the images:./Faces2//Geoff_Hoon/Geoff_Hoon_0007.jpg
# reading the images:./Faces2//Elizabeth_Hurley/Elizabeth_Hurley_0001.jpg
# reading the images:./Faces2//Elizabeth_Hurley/Elizabeth_Hurley_0002.jpg
# reading the images:./Faces2//Elizabeth_Hurley/Elizabeth_Hurley_0003.jpg
# reading the images:./Faces2//Elizabeth_Hurley/Elizabeth_Hurley_0004.jpg
# reading the images:./Faces2//Elizabeth_Hurley/Elizabeth_Hurley_0005.jpg
# reading the images:./Faces2//Hipolito_Mejia/Hipolito_Mejia_0004.jpg
# reading the images:./Faces2//Hipolito_Mejia/Hipolito_Mejia_0003.jpg
# reading the images:./Faces2//Hipolito_Mejia/Hipolito_Mejia_0002.jpg
# reading the images:./Faces2//Hipolito_Mejia/Hipolito_Mejia_0001.jpg
# reading the images:./Faces2//Bart_Hendricks/Bart_Hendricks_0001.jpg
# reading the images:./Faces2//David_Brown/David_Brown_0001.jpg
# reading the images:./Faces2//Craig_Burley/Craig_Burley_0001.jpg
# reading the images:./Faces2//Hermogenes_Ebdane_Jr/Hermogenes_Ebdane_Jr_0001.jpg
# reading the images:./Faces2//Joey_Harrington/Joey_Harrington_0001.jpg
# reading the images:./Faces2//Wolfgang_Schwarz/Wolfgang_Schwarz_0001.jpg
# reading the images:./Faces2//Sebastian_Saja/Sebastian_Saja_0002.jpg
# reading the images:./Faces2//Sebastian_Saja/Sebastian_Saja_0003.jpg
# reading the images:./Faces2//Sebastian_Saja/Sebastian_Saja_0001.jpg
# reading the images:./Faces2//Rick_Wagoner/Rick_Wagoner_0001.jpg
# reading the images:./Faces2//Rick_Wagoner/Rick_Wagoner_0002.jpg
# reading the images:./Faces2//Don_Henley/Don_Henley_0001.jpg
# reading the images:./Faces2//John_Baldacci/John_Baldacci_0001.jpg
# reading the images:./Faces2//Dustin_Brown/Dustin_Brown_0001.jpg
# reading the images:./Faces2//Dominic_Monaghan/Dominic_Monaghan_0001.jpg
# reading the images:./Faces2//Chris_Byrd/Chris_Byrd_0002.jpg
# reading the images:./Faces2//Chris_Byrd/Chris_Byrd_0001.jpg
# reading the images:./Faces2//Niall_Connolly/Niall_Connolly_0001.jpg
# reading the images:./Faces2//Richard_Palmer/Richard_Palmer_0001.jpg
# reading the images:./Faces2//Fazal-ur-Rehman/Fazal-ur-Rehman_0001.jpg
# reading the images:./Faces2//Boris_Jordan/Boris_Jordan_0001.jpg
# reading the images:./Faces2//Charlotte_Rampling/Charlotte_Rampling_0001.jpg
# reading the images:./Faces2//Charlotte_Rampling/Charlotte_Rampling_0002.jpg
# reading the images:./Faces2//Hutomo_Mandala_Putra/Hutomo_Mandala_Putra_0001.jpg
# reading the images:./Faces2//Lars_Burgsmuller/Lars_Burgsmuller_0001.jpg
# reading the images:./Faces2//Win_Aung/Win_Aung_0002.jpg
# reading the images:./Faces2//Win_Aung/Win_Aung_0003.jpg
# reading the images:./Faces2//Win_Aung/Win_Aung_0001.jpg
# reading the images:./Faces2//Jason_Statham/Jason_Statham_0001.jpg
# reading the images:./Faces2//Mike_Bair/Mike_Bair_0001.jpg
# reading the images:./Faces2//Yana_Klochkova/Yana_Klochkova_0001.jpg
# reading the images:./Faces2//Doug_Racine/Doug_Racine_0001.jpg
# reading the images:./Faces2//Elena_Likhovtseva/Elena_Likhovtseva_0001.jpg
# reading the images:./Faces2//Paul_Ebert/Paul_Ebert_0001.jpg
# reading the images:./Faces2//Anita_DeFrantz/Anita_DeFrantz_0001.jpg
# reading the images:./Faces2//Lee_Nam-shin/Lee_Nam-shin_0001.jpg
# reading the images:./Faces2//Crispin_Glover/Crispin_Glover_0001.jpg
# reading the images:./Faces2//Kevin_Marshall/Kevin_Marshall_0001.jpg
# reading the images:./Faces2//Sven_Ottke/Sven_Ottke_0001.jpg
# reading the images:./Faces2//Raf_Vallone/Raf_Vallone_0001.jpg
# reading the images:./Faces2//Nick_Reilly/Nick_Reilly_0001.jpg
# reading the images:./Faces2//Bob_Huggins/Bob_Huggins_0003.jpg
# reading the images:./Faces2//Bob_Huggins/Bob_Huggins_0002.jpg
# reading the images:./Faces2//Bob_Huggins/Bob_Huggins_0001.jpg
# reading the images:./Faces2//Bob_Huggins/Bob_Huggins_0004.jpg
# reading the images:./Faces2//David_Zeplowitz/David_Zeplowitz_0001.jpg
# reading the images:./Faces2//Tayshaun_Prince/Tayshaun_Prince_0001.jpg
# reading the images:./Faces2//Emmanuelle_Jagodsinski/Emmanuelle_Jagodsinski_0001.jpg
# reading the images:./Faces2//Lyle_Vanclief/Lyle_Vanclief_0001.jpg
# reading the images:./Faces2//Lyle_Vanclief/Lyle_Vanclief_0002.jpg
# reading the images:./Faces2//Paula_Locke/Paula_Locke_0001.jpg
# reading the images:./Faces2//James_Mathis/James_Mathis_0001.jpg
# reading the images:./Faces2//Lou_Piniella/Lou_Piniella_0001.jpg
# reading the images:./Faces2//Lou_Piniella/Lou_Piniella_0002.jpg
# reading the images:./Faces2//Lou_Piniella/Lou_Piniella_0003.jpg
# reading the images:./Faces2//Soenarno/Soenarno_0001.jpg
# reading the images:./Faces2//Tara_Reid/Tara_Reid_0001.jpg
# reading the images:./Faces2//Christian_Von_Wernich/Christian_Von_Wernich_0001.jpg
# reading the images:./Faces2//Jacques_Rogge/Jacques_Rogge_0008.jpg
# reading the images:./Faces2//Jacques_Rogge/Jacques_Rogge_0009.jpg
# reading the images:./Faces2//Jacques_Rogge/Jacques_Rogge_0001.jpg
# reading the images:./Faces2//Jacques_Rogge/Jacques_Rogge_0002.jpg
# reading the images:./Faces2//Jacques_Rogge/Jacques_Rogge_0003.jpg
# reading the images:./Faces2//Jacques_Rogge/Jacques_Rogge_0007.jpg
# reading the images:./Faces2//Jacques_Rogge/Jacques_Rogge_0006.jpg
# reading the images:./Faces2//Jacques_Rogge/Jacques_Rogge_0010.jpg
# reading the images:./Faces2//Jacques_Rogge/Jacques_Rogge_0004.jpg
# reading the images:./Faces2//Jacques_Rogge/Jacques_Rogge_0005.jpg
# reading the images:./Faces2//Nawabzada_Nasrullah_Khan/Nawabzada_Nasrullah_Khan_0001.jpg
# reading the images:./Faces2//Catherine_Donkers/Catherine_Donkers_0001.jpg
# reading the images:./Faces2//Agnelo_Queiroz/Agnelo_Queiroz_0001.jpg
# reading the images:./Faces2//Henry_Hilow/Henry_Hilow_0001.jpg
# reading the images:./Faces2//Eric_Hinske/Eric_Hinske_0001.jpg
# reading the images:./Faces2//Eric_Hinske/Eric_Hinske_0002.jpg
# reading the images:./Faces2//Chris_Cornell/Chris_Cornell_0001.jpg
# reading the images:./Faces2//Bonnie_Fuller/Bonnie_Fuller_0001.jpg
# reading the images:./Faces2//Matt_Morris/Matt_Morris_0001.jpg
# reading the images:./Faces2//Harbhajan_Singh/Harbhajan_Singh_0001.jpg
# reading the images:./Faces2//Harbhajan_Singh/Harbhajan_Singh_0002.jpg
# reading the images:./Faces2//Kim_Dong-hwa/Kim_Dong-hwa_0001.jpg
# reading the images:./Faces2//Tim_Matheson/Tim_Matheson_0001.jpg
# reading the images:./Faces2//Dick_Smothers/Dick_Smothers_0001.jpg
# reading the images:./Faces2//Jia_Qinglin/Jia_Qinglin_0002.jpg
# reading the images:./Faces2//Jia_Qinglin/Jia_Qinglin_0001.jpg
# reading the images:./Faces2//Gerald_Calabrese/Gerald_Calabrese_0001.jpg
# reading the images:./Faces2//Rowan_Williams/Rowan_Williams_0001.jpg
# reading the images:./Faces2//Peter_Goldmark/Peter_Goldmark_0001.jpg
# reading the images:./Faces2//Brian_Van_Dusen/Brian_Van_Dusen_0001.jpg
# reading the images:./Faces2//Osama_bin_Laden/Osama_bin_Laden_0002.jpg
# reading the images:./Faces2//Osama_bin_Laden/Osama_bin_Laden_0003.jpg
# reading the images:./Faces2//Osama_bin_Laden/Osama_bin_Laden_0001.jpg
# reading the images:./Faces2//Osama_bin_Laden/Osama_bin_Laden_0004.jpg
# reading the images:./Faces2//Stanley_McChrystal/Stanley_McChrystal_0002.jpg
# reading the images:./Faces2//Stanley_McChrystal/Stanley_McChrystal_0003.jpg
# reading the images:./Faces2//Stanley_McChrystal/Stanley_McChrystal_0001.jpg
# reading the images:./Faces2//Carlos_Ghosn/Carlos_Ghosn_0001.jpg
# reading the images:./Faces2//Carlos_Ghosn/Carlos_Ghosn_0002.jpg
# reading the images:./Faces2//Jean_Todt/Jean_Todt_0001.jpg
# reading the images:./Faces2//Wally_Szczerbiak/Wally_Szczerbiak_0001.jpg
# reading the images:./Faces2//Zara_Akhmadova/Zara_Akhmadova_0001.jpg
# reading the images:./Faces2//Donald_Keck/Donald_Keck_0001.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_0004.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_0010.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_0011.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_0005.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_0013.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_0007.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_0006.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_0012.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_0002.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_0003.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_0001.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_0015.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_0014.jpg
# reading the images:./Faces2//Andy_Roddick/Andy_Roddick_
# reading the images:./Faces2//Noor_Mohammed/Noor_Mohammed_0001.jpg
# reading the images:./Faces2//Walt_Harris/Walt_Harris_0001.jpg
# reading the images:./Faces2//Olivera_Labus/Olivera_Labus_0001.jpg
# reading the images:./Faces2//Stephen_Covey/Stephen_Covey_0001.jpg
# reading the images:./Faces2//Woodrow_Stanley/Woodrow_Stanley_0001.jpg
# reading the images:./Faces2//Yuvraj_Singh/Yuvraj_Singh_0001.jpg
# reading the images:./Faces2//Bobby_Bowden/Bobby_Bowden_0001.jpg
# reading the images:./Faces2//Hussein_Malik/Hussein_Malik_0001.jpg
# reading the images:./Faces2//Tom_Hanks/Tom_Hanks_0009.jpg
# reading the images:./Faces2//Tom_Hanks/Tom_Hanks_0008.jpg
# reading the images:./Faces2//Tom_Hanks/Tom_Hanks_0001.jpg
# reading the images:./Faces2//Tom_Hanks/Tom_Hanks_0003.jpg
# reading the images:./Faces2//Tom_Hanks/Tom_Hanks_0002.jpg
# reading the images:./Faces2//Tom_Hanks/Tom_Hanks_0006.jpg
# reading the images:./Faces2//Tom_Hanks/Tom_Hanks_0007.jpg
# reading the images:./Faces2//Tom_Hanks/Tom_Hanks_0005.jpg
# reading the images:./Faces2//Tom_Hanks/Tom_Hanks_0004.jpg
# reading the images:./Faces2//Tom_Hanks/Tom_Hanks_0010.jpg
# reading the images:./Faces2//Gary_Gitnick/Gary_Gitnick_0001.jpg
# reading the images:./Faces2//Mike_Richter/Mike_Richter_0001.jpg
# reading the images:./Faces2//Luke_Walton/Luke_Walton_0001.jpg
# reading the images:./Faces2//Luke_Walton/Luke_Walton_0002.jpg
# reading the images:./Faces2//Denys_Arcand/Denys_Arcand_0001.jpg
# reading the images:./Faces2//Bill_Butler/Bill_Butler_0001.jpg
# reading the images:./Faces2//Michael_Goldrich/Michael_Goldrich_0001.jpg
# reading the images:./Faces2//Yekaterina_Guseva/Yekaterina_Guseva_0001.jpg
# reading the images:./Faces2//Darren_Clarke/Darren_Clarke_0001.jpg
# reading the images:./Faces2//Darren_Clarke/Darren_Clarke_0002.jpg
# reading the images:./Faces2//Intisar_Ajouri/Intisar_Ajouri_0002.jpg
# reading the images:./Faces2//Intisar_Ajouri/Intisar_Ajouri_0003.jpg
# reading the images:./Faces2//Intisar_Ajouri/Intisar_Ajouri_0001.jpg
# reading the images:./Faces2//Cristiano_da_Matta/Cristiano_da_Matta_0001.jpg
# reading the images:./Faces2//Hugh_Carey/Hugh_Carey_0001.jpg
# reading the images:./Faces2//Danny_Glover/Danny_Glover_0001.jpg
# reading the images:./Faces2//Peter_Hunt/Peter_Hunt_0001.jpg
# reading the images:./Faces2//Steven_Feldman/Steven_Feldman_0001.jpg
# reading the images:./Faces2//Dinah_Turner/Dinah_Turner_0001.jpg
# reading the images:./Faces2//Rosny_Desroches/Rosny_Desroches_0001.jpg
# reading the images:./Faces2//Cosmo_Iacavazzi/Cosmo_Iacavazzi_0001.jpg
# reading the images:./Faces2//Daniel_Day-Lewis/Daniel_Day-Lewis_0001.jpg
# reading the images:./Faces2//Shae-Lynn_Bourne/Shae-Lynn_Bourne_0001.jpg
# reading the images:./Faces2//Bob_Sulkin/Bob_Sulkin_0001.jpg
# reading the images:./Faces2//Chakib_Khelil/Chakib_Khelil_0001.jpg
# reading the images:./Faces2//Chakib_Khelil/Chakib_Khelil_0002.jpg
# reading the images:./Faces2//Robert_Wagner/Robert_Wagner_0001.jpg
# reading the images:./Faces2//William_Cocksedge/William_Cocksedge_0001.jpg
# reading the images:./Faces2//Giselle_Estefania_Tavarelli/Giselle_Estefania_Tavarelli_0001.jpg
# reading the images:./Faces2//Lorne_Michaels/Lorne_Michaels_0001.jpg
# reading the images:./Faces2//Ricky_Barnes/Ricky_Barnes_0002.jpg
# reading the images:./Faces2//Ricky_Barnes/Ricky_Barnes_0001.jpg
# reading the images:./Faces2//Laura_Ziskin/Laura_Ziskin_0001.jpg
# reading the images:./Faces2//Ray_Evernham/Ray_Evernham_0001.jpg
# reading the images:./Faces2//Pedro_Velasquez/Pedro_Velasquez_0001.jpg
# reading the images:./Faces2//Marion_Fahnestock/Marion_Fahnestock_0001.jpg
# reading the images:./Faces2//Jane_Pauley/Jane_Pauley_0002.jpg
# reading the images:./Faces2//Jane_Pauley/Jane_Pauley_0001.jpg
# reading the images:./Faces2//Bernardo_Segura/Bernardo_Segura_0002.jpg
# reading the images:./Faces2//Bernardo_Segura/Bernardo_Segura_0001.jpg
# reading the images:./Faces2//Padraig_Harrington/Padraig_Harrington_0001.jpg
# reading the images:./Faces2//Padraig_Harrington/Padraig_Harrington_0003.jpg
# reading the images:./Faces2//Padraig_Harrington/Padraig_Harrington_0002.jpg
# reading the images:./Faces2//Padraig_Harrington/Padraig_Harrington_0004.jpg
# reading the images:./Faces2//Luke_Smith/Luke_Smith_0001.jpg
# reading the images:./Faces2//Brandon_Boyd/Brandon_Boyd_0001.jpg
# reading the images:./Faces2//Jim_Jeffords/Jim_Jeffords_0001.jpg
# reading the images:./Faces2//Claudio_Abbado/Claudio_Abbado_0001.jpg
# reading the images:./Faces2//Chen_Liang_Yu/Chen_Liang_Yu_0001.jpg
# reading the images:./Faces2//Chen_Liang_Yu/Chen_Liang_Yu_0002.jpg
# reading the images:./Faces2//Maura_Tierney/Maura_Tierney_0001.jpg
# reading the images:./Faces2//John_Danforth/John_Danforth_0001.jpg
# reading the images:./Faces2//Cheryl_Hines/Cheryl_Hines_0001.jpg
# reading the images:./Faces2//Timothy_Goebel/Timothy_Goebel_0001.jpg
# reading the images:./Faces2//Frank_Sinatra/Frank_Sinatra_0001.jpg
# reading the images:./Faces2//Marissa_Jaret_Winokur/Marissa_Jaret_Winokur_0001.jpg
# reading the images:./Faces2//Marissa_Jaret_Winokur/Marissa_Jaret_Winokur_0002.jpg
# reading the images:./Faces2//Masamori_Tokuyama/Masamori_Tokuyama_0001.jpg
# reading the images:./Faces2//Bill_Rainer/Bill_Rainer_0001.jpg
# reading the images:./Faces2//Ken_Watanabe/Ken_Watanabe_0002.jpg
# reading the images:./Faces2//Ken_Watanabe/Ken_Watanabe_0001.jpg
# reading the images:./Faces2//Kimora_Lee/Kimora_Lee_0001.jpg
# reading the images:./Faces2//Sanjay_Gupta/Sanjay_Gupta_0001.jpg
# reading the images:./Faces2//Gary_Locke/Gary_Locke_0001.jpg
# reading the images:./Faces2//Gary_Locke/Gary_Locke_0002.jpg
# reading the images:./Faces2//Sinead_OConnor/Sinead_OConnor_0001.jpg
# reading the images:./Faces2//James_W_Kennedy/James_W_Kennedy_0001.jpg
# reading the images:./Faces2//Kurt_Suzuki/Kurt_Suzuki_0001.jpg
# reading the images:./Faces2//Frederick_Madden/Frederick_Madden_0001.jpg
# reading the images:./Faces2//Priscilla_Owen/Priscilla_Owen_0002.jpg
# reading the images:./Faces2//Priscilla_Owen/Priscilla_Owen_0001.jpg
# reading the images:./Faces2//Malcolm_Jamal_Warner/Malcolm_Jamal_Warner_0001.jpg
# reading the images:./Faces2//Naoto_Kan/Naoto_Kan_0003.jpg
# reading the images:./Faces2//Naoto_Kan/Naoto_Kan_0002.jpg
# reading the images:./Faces2//Naoto_Kan/Naoto_Kan_0001.jpg
# reading the images:./Faces2//Naoto_Kan/Naoto_Kan_0004.jpg
# reading the images:./Faces2//Sue_Guevara/Sue_Guevara_0001.jpg
# reading the images:./Faces2//John_Sweeney/John_Sweeney_0001.jpg
# reading the images:./Faces2//Brian_Cashman/Brian_Cashman_0001.jpg
# reading the images:./Faces2//Marco_Pantani/Marco_Pantani_0001.jpg
# reading the images:./Faces2//Theodore_Tweed_Roosevelt/Theodore_Tweed_Roosevelt_0002.jpg
# reading the images:./Faces2//Theodore_Tweed_Roosevelt/Theodore_Tweed_Roosevelt_0003.jpg
# reading the images:./Faces2//Theodore_Tweed_Roosevelt/Theodore_Tweed_Roosevelt_0001.jpg
# reading the images:./Faces2//Se_Hyuk_Joo/Se_Hyuk_Joo_0001.jpg
# reading the images:./Faces2//Ian_Moran/Ian_Moran_0001.jpg
# reading the images:./Faces2//Michael_Olowokandi/Michael_Olowokandi_0001.jpg
# reading the images:./Faces2//James_Brosnahan/James_Brosnahan_0001.jpg
# reading the images:./Faces2//Kevin_Nealon/Kevin_Nealon_0001.jpg
# reading the images:./Faces2//Miguel_Estrada/Miguel_Estrada_0001.jpg
# reading the images:./Faces2//Miguel_Estrada/Miguel_Estrada_0002.jpg
# reading the images:./Faces2//Alison_Krauss/Alison_Krauss_0001.jpg
# reading the images:./Faces2//Bill_Callahan/Bill_Callahan_0001.jpg
# reading the images:./Faces2//Bill_Callahan/Bill_Callahan_0002.jpg
# reading the images:./Faces2//Bill_Callahan/Bill_Callahan_0003.jpg
# reading the images:./Faces2//Allison_Searing/Allison_Searing_0001.jpg
# reading the images:./Faces2//Torri_Edwards/Torri_Edwards_0002.jpg
# reading the images:./Faces2//Torri_Edwards/Torri_Edwards_0001.jpg
# reading the images:./Faces2//Bryan_Thomas/Bryan_Thomas_0001.jpg
# reading the images:./Faces2//Kathy_Baker/Kathy_Baker_0001.jpg
# reading the images:./Faces2//Martha_Stewart/Martha_Stewart_0005.jpg
# reading the images:./Faces2//Martha_Stewart/Martha_Stewart_0004.jpg
# reading the images:./Faces2//Martha_Stewart/Martha_Stewart_0001.jpg
# ...
# reading the images:./Faces2//Peter_Arnett/Peter_Arnett_0001.jpg
# reading the images:./Faces2//Abdul_Rahman/Abdul_Rahman_0001.jpg
# reading the images:./Faces2//Filip_De_Winter/Filip_De_Winter_0001.jpg
# reading the images:./Faces2//Jerry_Hall/Jerry_Hall_0001.jpg
# reading the images:./Faces2//Tim_Howard/Tim_Howard_0001.jpg
# reading the images:./Faces2//Daniel_Montenegro/Daniel_Montenegro_0001.jpg
# reading the images:./Faces2//Malcolm_Glazer/Malcolm_Glazer_0001.jpg
# reading the images:./Faces2//Melissa_Manchester/Melissa_Manchester_0001.jpg
# reading the images:./Faces2//Estelle_Morris/Estelle_Morris_0001.jpg
# reading the images:./Faces2//Solomon_Passy/Solomon_Passy_0001.jpg
# reading the images:./Faces2//Faye_Alibocus/Faye_Alibocus_0001.jpg
# reading the images:./Faces2//Bill_Lerach/Bill_Lerach_0001.jpg
# reading the images:./Faces2//Hamid_Efendi/Hamid_Efendi_0001.jpg
# reading the images:./Faces2//Lon_Kruger/Lon_Kruger_0002.jpg
# reading the images:./Faces2//Lon_Kruger/Lon_Kruger_0001.jpg
# reading the images:./Faces2//Bernard_Lord/Bernard_Lord_0001.jpg
# reading the images:./Faces2//Bernard_Lord/Bernard_Lord_0002.jpg
# reading the images:./Faces2//Fernando_Valenzuela/Fernando_Valenzuela_0001.jpg
# reading the images:./Faces2//John_Brady/John_Brady_0001.jpg
# reading the images:./Faces2//John_Brady/John_Brady_0002.jpg
# reading the images:./Faces2//Hassanal_Bolkiah/Hassanal_Bolkiah_0001.jpg
# reading the images:./Faces2//Nelson_Acosta/Nelson_Acosta_0001.jpg
# reading the images:./Faces2//Mo_Elleithee/Mo_Elleithee_0001.jpg
# reading the images:./Faces2//Klaus_Zwickel/Klaus_Zwickel_0002.jpg
# reading the images:./Faces2//Klaus_Zwickel/Klaus_Zwickel_0001.jpg
# reading the images:./Faces2//Kristanna_Loken/Kristanna_Loken_0004.jpg
# reading the images:./Faces2//Kristanna_Loken/Kristanna_Loken_0005.jpg
# reading the images:./Faces2//Kristanna_Loken/Kristanna_Loken_0001.jpg
# reading the images:./Faces2//Kristanna_Loken/Kristanna_Loken_0002.jpg
# reading the images:./Faces2//Kristanna_Loken/Kristanna_Loken_0003.jpg
# reading the images:./Faces2//Johnny_Htu/Johnny_Htu_0001.jpg
# reading the images:./Faces2//Francisco_Flores/Francisco_Flores_0004.jpg
# reading the images:./Faces2//Francisco_Flores/Francisco_Flores_0003.jpg
# reading the images:./Faces2//Francisco_Flores/Francisco_Flores_0002.jpg
# reading the images:./Faces2//Francisco_Flores/Francisco_Flores_0001.jpg
# reading the images:./Faces2//Adrien_Brody/Adrien_Brody_0012.jpg
# reading the images:./Faces2//Adrien_Brody/Adrien_Brody_0006.jpg
# reading the images:./Faces2//Adrien_Brody/Adrien_Brody_0007.jpg
# reading the images:./Faces2//Adrien_Brody/Adrien_Brody_0005.jpg
# reading the images:./Faces2//Adrien_Brody/Adrien_Brody_0011.jpg
# reading the images:./Faces2//Adrien_Brody/Adrien_Brody_0010.jpg
# reading the images:./Faces2//Adrien_Brody/Adrien_Brody_0004.jpg
# reading the images:./Faces2//Adrien_Brody/Adrien_Brody_0001.jpg
# reading the images:./Faces2//Adrien_Brody/Adrien_Brody_0003.jpg
# reading the images:./Faces2//Adrien_Brody/Adrien_Brody_0002.jpg
# reading the images:./Faces2//Adrien_Brody/Adrien_Brody_0009.jpg
# reading the images:./Faces2//Adrien_Brody/Adrien_Brody_0008.jpg
# reading the images:./Faces2//Hosni_Mubarak/Hosni_Mubarak_0007.jpg
# reading the images:./Faces2//Hosni_Mubarak/Hosni_Mubarak_0006.jpg
# reading the images:./Faces2//Hosni_Mubarak/Hosni_Mubarak_0004.jpg
# reading the images:./Faces2//Hosni_Mubarak/Hosni_Mubarak_0005.jpg
# reading the images:./Faces2//Hosni_Mubarak/Hosni_Mubarak_0001.jpg
# reading the images:./Faces2//Hosni_Mubarak/Hosni_Mubarak_0002.jpg
# reading the images:./Faces2//Hosni_Mubarak/Hosni_Mubarak_0003.jpg
# reading the images:./Faces2//Hosni_Mubarak/Hosni_Mubarak_0008.jpg
# reading the images:./Faces2//Hosni_Mubarak/Hosni_Mubarak_0009.jpg
# reading the images:./Faces2//Ward_Cuff/Ward_Cuff_0001.jpg
# reading the images:./Faces2//Jason_Priestley/Jason_Priestley_0001.jpg
# reading the images:./Faces2//Adrian_Annus/Adrian_Annus_0001.jpg
# reading the images:./Faces2//Sean_Penn/Sean_Penn_0002.jpg
# reading the images:./Faces2//Sean_Penn/Sean_Penn_0003.jpg
# reading the images:./Faces2//Sean_Penn/Sean_Penn_0001.jpg
# reading the images:./Faces2//Mark_Heller/Mark_Heller_0001.jpg
# reading the images:./Faces2//Donnie_Brennan/Donnie_Brennan_0001.jpg
# reading the images:./Faces2//Michael_Michele/Michael_Michele_0001.jpg
# reading the images:./Faces2//Martin_Brodeur/Martin_Brodeur_0001.jpg
# reading the images:./Faces2//Martin_Brodeur/Martin_Brodeur_0002.jpg
# reading the images:./Faces2//Kirk_Franklin/Kirk_Franklin_0001.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0019.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0018.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0024.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0008.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0020.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0021.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0009.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0023.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0022.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0013.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0007.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0006.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0012.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0004.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0010.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0011.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0005.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0001.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0015.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0014.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0016.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0002.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0003.jpg
# reading the images:./Faces2//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0017.jpg
# reading the images:./Faces2//Paul_Li_Calsi/Paul_Li_Calsi_0001.jpg
# reading the images:./Faces2//William_Nessen/William_Nessen_0001.jpg
# reading the images:./Faces2//Bob_Goldman/Bob_Goldman_0001.jpg
# reading the images:./Faces2//Scott_Dickson/Scott_Dickson_0001.jpg
# reading the images:./Faces2//Grady_Little/Grady_Little_0001.jpg
# reading the images:./Faces2//John_Philip_Elkann/John_Philip_Elkann_0001.jpg
# reading the images:./Faces2//Shane_Mosley/Shane_Mosley_0001.jpg
# reading the images:./Faces2//Shane_Mosley/Shane_Mosley_0002.jpg
# reading the images:./Faces2//Cathryn_Crawford/Cathryn_Crawford_0001.jpg
# reading the images:./Faces2//Bill_Pryor/Bill_Pryor_0001.jpg
# reading the images:./Faces2//Camilla_Parker_Bowles/Camilla_Parker_Bowles_0001.jpg
# reading the images:./Faces2//Camilla_Parker_Bowles/Camilla_Parker_Bowles_0002.jpg
# reading the images:./Faces2//Zhu_Rongji/Zhu_Rongji_0008.jpg
# reading the images:./Faces2//Zhu_Rongji/Zhu_Rongji_0009.jpg
# reading the images:./Faces2//Zhu_Rongji/Zhu_Rongji_0007.jpg
# reading the images:./Faces2//Zhu_Rongji/Zhu_Rongji_0006.jpg
# reading the images:./Faces2//Zhu_Rongji/Zhu_Rongji_0004.jpg
# reading the images:./Faces2//Zhu_Rongji/Zhu_Rongji_0005.jpg
# reading the images:./Faces2//Zhu_Rongji/Zhu_Rongji_0001.jpg
# reading the images:./Faces2//Zhu_Rongji/Zhu_Rongji_0002.jpg
# reading the images:./Faces2//Zhu_Rongji/Zhu_Rongji_0003.jpg
# reading the images:./Faces2//Margaret_Hasley/Margaret_Hasley_0001.jpg
# reading the images:./Faces2//Lee_Byung-woong/Lee_Byung-woong_0001.jpg
# reading the images:./Faces2//Serge_Klarsfeld/Serge_Klarsfeld_0001.jpg
# reading the images:./Faces2//Nikki_Cascone/Nikki_Cascone_0001.jpg
# reading the images:./Faces2//Alberta_Lee/Alberta_Lee_0001.jpg
# reading the images:./Faces2//Nick_Price/Nick_Price_0001.jpg
# reading the images:./Faces2//Shane_Reynolds/Shane_Reynolds_0001.jpg
# reading the images:./Faces2//Russ_Ortiz/Russ_Ortiz_0001.jpg
# reading the images:./Faces2//Sonya_Walger/Sonya_Walger_0001.jpg
# reading the images:./Faces2//Johnson_Panjaitan/Johnson_Panjaitan_0002.jpg
# reading the images:./Faces2//Johnson_Panjaitan/Johnson_Panjaitan_0001.jpg
# reading the images:./Faces2//Joan_Claybrook/Joan_Claybrook_0002.jpg
# reading the images:./Faces2//Joan_Claybrook/Joan_Claybrook_0001.jpg
# reading the images:./Faces2//Andrea_Bocelli/Andrea_Bocelli_0001.jpg
# reading the images:./Faces2//Michael_McNeely/Michael_McNeely_0001.jpg
# reading the images:./Faces2//Andy_Lau/Andy_Lau_0001.jpg
# reading the images:./Faces2//Jimmy_Kimmel/Jimmy_Kimmel_0001.jpg
# reading the images:./Faces2//Jimmy_Kimmel/Jimmy_Kimmel_0002.jpg
# reading the images:./Faces2//Albrecht_Mentz/Albrecht_Mentz_0002.jpg
# reading the images:./Faces2//Albrecht_Mentz/Albrecht_Mentz_0001.jpg
# reading the images:./Faces2//Hank_Azaria/Hank_Azaria_0001.jpg
# reading the images:./Faces2//Doris_Schroeder/Doris_Schroeder_0003.jpg
# reading the images:./Faces2//Doris_Schroeder/Doris_Schroeder_0002.jpg
# reading the images:./Faces2//Doris_Schroeder/Doris_Schroeder_0001.jpg
# reading the images:./Faces2//Doris_Schroeder/Doris_Schroeder_0004.jpg
# reading the images:./Faces2//Sedigh_Barmak/Sedigh_Barmak_0001.jpg
# reading the images:./Faces2//Frank_Marshall/Frank_Marshall_0001.jpg
# reading the images:./Faces2//Sybille_Schmid/Sybille_Schmid_0001.jpg
# reading the images:./Faces2//Jerry_Sloan/Jerry_Sloan_0001.jpg
# reading the images:./Faces2//Dot_Helms/Dot_Helms_0001.jpg
# reading the images:./Faces2//Imad_Khadduri/Imad_Khadduri_0001.jpg
# reading the images:./Faces2//Hilary_McKay/Hilary_McKay_0001.jpg
# reading the images:./Faces2//Matthew_Vaughan/Matthew_Vaughan_0001.jpg
# reading the images:./Faces2//Jim_Parque/Jim_Parque_0001.jpg
# reading the images:./Faces2//Wycliffe_Grousbeck/Wycliffe_Grousbeck_0001.jpg
# reading the images:./Faces2//Buford_Blount/Buford_Blount_0001.jpg
# reading the images:./Faces2//Mike_Brey/Mike_Brey_0001.jpg
# reading the images:./Faces2//Mike_Brey/Mike_Brey_0002.jpg
# reading the images:./Faces2//Bill_Clancy/Bill_Clancy_0001.jpg
# reading the images:./Faces2//Michael_Jordan/Michael_Jordan_0001.jpg
# reading the images:./Faces2//Michael_Jordan/Michael_Jordan_0002.jpg
# reading the images:./Faces2//Michael_Jordan/Michael_Jordan_0003.jpg
# reading the images:./Faces2//Michael_Jordan/Michael_Jordan_0004.jpg
# reading the images:./Faces2//Bobby_Kielty/Bobby_Kielty_0001.jpg
# reading the images:./Faces2//Patti_Lank/Patti_Lank_0001.jpg
# reading the images:./Faces2//David_Arquette/David_Arquette_0001.jpg
# reading the images:./Faces2//Tracee_Ellis_Ross/Tracee_Ellis_Ross_0001.jpg
# reading the images:./Faces2//Tracee_Ellis_Ross/Tracee_Ellis_Ross_0002.jpg
# reading the images:./Faces2//Alain_Ducasse/Alain_Ducasse_0001.jpg
# reading the images:./Faces2//Mack_Brown/Mack_Brown_0002.jpg
# reading the images:./Faces2//Mack_Brown/Mack_Brown_0001.jpg
# reading the images:./Faces2//Aly_Wagner/Aly_Wagner_0001.jpg
# reading the images:./Faces2//Phil_Bredesen/Phil_Bredesen_0001.jpg
# reading the images:./Faces2//Natalie_Coughlin/Natalie_Coughlin_0001.jpg
# reading the images:./Faces2//Natalie_Coughlin/Natalie_Coughlin_0002.jpg
# reading the images:./Faces2//Natalie_Coughlin/Natalie_Coughlin_0003.jpg
# reading the images:./Faces2//Natalie_Coughlin/Natalie_Coughlin_0006.jpg
# reading the images:./Faces2//Natalie_Coughlin/Natalie_Coughlin_0004.jpg
# reading the images:./Faces2//Natalie_Coughlin/Natalie_Coughlin_0005.jpg
# reading the images:./Faces2//Marcus_Garrettson/Marcus_Garrettson_0001.jpg
# reading the images:./Faces2//Darryl_McDaniels/Darryl_McDaniels_0001.jpg
# reading the images:./Faces2//John_Jumper/John_Jumper_0002.jpg
# reading the images:./Faces2//John_Jumper/John_Jumper_0001.jpg
# reading the images:./Faces2//Bobby_Robson/Bobby_Robson_0001.jpg
# reading the images:./Faces2//Bobby_Robson/Bobby_Robson_0002.jpg
# reading the images:./Faces2//Patty_Duke/Patty_Duke_0001.jpg
# reading the images:./Faces2//Mike_Eskew/Mike_Eskew_0001.jpg
# reading the images:./Faces2//James_Smith/James_Smith_0002.jpg
# reading the images:./Faces2//James_Smith/James_Smith_0001.jpg
# reading the images:./Faces2//David_Bisbal/David_Bisbal_0001.jpg
# reading the images:./Faces2//Guy_Hemmings/Guy_Hemmings_0001.jpg
# reading the images:./Faces2//Guy_Hemmings/Guy_Hemmings_0002.jpg
